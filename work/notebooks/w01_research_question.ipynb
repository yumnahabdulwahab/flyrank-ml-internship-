# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yumnahabdulwahab/flyrank-ml-internship-/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## My Lane

Freestyle

I want to explore how search behaviour and page-level features can help identify content that best satisfies user intent. Rather than focusing only on search rankings, I want to understand which characteristics make pages more useful and valuable for users. This aligns with my interest in building AI-powered decision-support systems and recommendation applications that solve real-world problems through data-driven insights.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## Research Question

My research question is: Which page-level characteristics are most strongly associated with better search performance and user engagement?

The decision this research supports is identifying which pages should be prioritised for optimisation. The primary users of these insights are SEO specialists, content teams, and digital marketers who need to improve search visibility and user experience.

A wrong recommendation could result in valuable resources being spent optimising the wrong pages, reduced organic traffic, and missed opportunities to improve user satisfaction. Machine learning can help discover patterns across many page characteristics that would be difficult to identify manually.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## Careful Words

This project aims to identify observed patterns and relationships within the available search data that may support better decision-making. The results should be interpreted as decision-support rather than proof of causation.

The model will not predict Google's ranking algorithm or guarantee future search performance. Instead, it will provide evidence-based insights that may help prioritise optimisation efforts based on measurable patterns found in the dataset.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
